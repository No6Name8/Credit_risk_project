# %% [markdown]
# # Train + Evaluate Notebook (Template)\nYou can run the pipeline via scripts (`python -m src.train`, etc.), or replicate here in notebooks for reporting.\n

# %%
# !python -m src.train --data_path data/raw/dataset.csv --target TARGET\n!python -m src.evaluate --run_dir runs/latest\n!python -m src.explain --run_dir runs/latest\n
