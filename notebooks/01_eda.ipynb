# %% [markdown]
# # EDA Notebook (Template)\nLoad your dataset from `data/raw/dataset.csv`, inspect class balance, missing values, and feature distributions.\nSave 2–4 key figures into `reports/figures/` for the IEEE paper.\n

# %%
import pandas as pd\ndf = pd.read_csv('../data/raw/dataset.csv')\ndf.head()\n
